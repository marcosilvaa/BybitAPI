# %%
from BybitAPI.get_data import MarketData
import numpy as np

# %%
md = MarketData()

# %%
md.symbols_list()
# Out:
#          symbol baseCoin quoteCoin innovation   status marginTrading stTag  \
# 0       BTCUSDT      BTC      USDT          0  Trading       utaOnly     0
# 1       ETHUSDT      ETH      USDT          0  Trading       utaOnly     0
# 2       XRPUSDT      XRP      USDT          0  Trading       utaOnly     0
# 3        ETHBTC      ETH       BTC          0  Trading       utaOnly     0
# 4        XRPBTC      XRP       BTC          0  Trading       utaOnly     0
# ..          ...      ...       ...        ...      ...           ...   ...
# 681     METUSDC      MET      USDC          0  Trading          none     0
# 682  COMMONUSDT   COMMON      USDT          0  Trading          none     0
# 683    SYNDUSDT     SYND      USDT          0  Trading          none     0
# 684     EATUSDT      EAT      USDT          0  Trading          none     0
# 685     MMTUSDT      MMT      USDT          0  Trading          none     0
#
#                                          lotSizeFilter  \
# 0    {'basePrecision': '0.000001', 'quotePrecision'...
# 1    {'basePrecision': '0.00001', 'quotePrecision':...
# 2    {'basePrecision': '0.01', 'quotePrecision': '0...
# 3    {'basePrecision': '0.00001', 'quotePrecision':...
# 4    {'basePrecision': '0.01', 'quotePrecision': '0...
# ..                                                 ...
# 681  {'basePrecision': '0.1', 'quotePrecision': '0....
# 682  {'basePrecision': '0.1', 'quotePrecision': '0....
# 683  {'basePrecision': '0.1', 'quotePrecision': '0....
# 684  {'basePrecision': '0.1', 'quotePrecision': '0....
# 685  {'basePrecision': '0.1', 'quotePrecision': '0....
#
#                     priceFilter  \
# 0           {'tickSize': '0.1'}
# 1          {'tickSize': '0.01'}
# 2        {'tickSize': '0.0001'}
# 3      {'tickSize': '0.000001'}
# 4    {'tickSize': '0.00000001'}
# ..                          ...
# 681      {'tickSize': '0.0001'}
# 682     {'tickSize': '0.00001'}
# 683      {'tickSize': '0.0001'}
# 684     {'tickSize': '0.00001'}
# 685      {'tickSize': '0.0001'}
#
#                                         riskParameters symbolType
# 0    {'priceLimitRatioX': '0.005', 'priceLimitRatio...
# 1    {'priceLimitRatioX': '0.005', 'priceLimitRatio...
# 2    {'priceLimitRatioX': '0.01', 'priceLimitRatioY...
# 3    {'priceLimitRatioX': '0.005', 'priceLimitRatio...
# 4    {'priceLimitRatioX': '0.01', 'priceLimitRatioY...
# ..                                                 ...        ...
# 681  {'priceLimitRatioX': '0.05', 'priceLimitRatioY...
# 682  {'priceLimitRatioX': '0.05', 'priceLimitRatioY...
# 683  {'priceLimitRatioX': '0.05', 'priceLimitRatioY...
# 684  {'priceLimitRatioX': '0.05', 'priceLimitRatioY...
# 685  {'priceLimitRatioX': '0.05', 'priceLimitRatioY...
#
# [686 rows x 11 columns]

# %%
btc = md.price_data(symbol='BTCUSDT',category='spot', interval='D')
btc.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
md.price_data(symbol='BTCUSDT', interval='D', category='spot')
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-02-09 21:00:00-03:00   21796.73   21934.41   21480.00   21631.49
# 2023-02-10 21:00:00-03:00   21631.49   21899.60   21607.94   21863.97
# 2023-02-11 21:00:00-03:00   21863.97   22084.19   21637.60   21780.45
# 2023-02-12 21:00:00-03:00   21780.45   21888.60   21360.00   21774.06
# 2023-02-13 21:00:00-03:00   21774.06   22311.67   21533.86   22199.85
# ...                              ...        ...        ...        ...
# 2025-10-31 21:00:00-03:00  109603.10  110564.50  109385.70  110092.30
# 2025-11-01 21:00:00-03:00  110092.30  111236.50  109492.10  110539.90
# 2025-11-02 21:00:00-03:00  110539.90  110761.50  105307.40  106581.40
# 2025-11-03 21:00:00-03:00  106581.40  107294.20   98947.80  101491.70
# 2025-11-04 21:00:00-03:00  101491.70  104040.00   98961.70  103572.50
#
#                                  Volume
# Date
# 2023-02-09 21:00:00-03:00   4124.474714
# 2023-02-10 21:00:00-03:00   1343.038651
# 2023-02-11 21:00:00-03:00   1985.985647
# 2023-02-12 21:00:00-03:00   3767.184413
# 2023-02-13 21:00:00-03:00   4427.940576
# ...                                 ...
# 2025-10-31 21:00:00-03:00   3228.236938
# 2025-11-01 21:00:00-03:00   4242.129321
# 2025-11-02 21:00:00-03:00  11651.770170
# 2025-11-03 21:00:00-03:00  16369.162834
# 2025-11-04 21:00:00-03:00   8774.003307
#
# [1000 rows x 5 columns]

# %%
md.price_data(symbol='BTCUSDT', interval='1', category='linear')
# Out:
#                                Open      High       Low     Close   Volume
# Date
# 2025-11-04 21:39:00-03:00  100757.0  100777.1  100650.6  100695.7   46.169
# 2025-11-04 21:40:00-03:00  100695.7  100720.0  100616.7  100630.0   39.508
# 2025-11-04 21:41:00-03:00  100630.0  100630.1  100455.0  100499.9  117.673
# 2025-11-04 21:42:00-03:00  100499.9  100570.0  100496.2  100521.9  104.796
# 2025-11-04 21:43:00-03:00  100521.9  100528.5  100334.0  100490.9  223.573
# ...                             ...       ...       ...       ...      ...
# 2025-11-05 14:14:00-03:00  103427.9  103446.4  103350.0  103415.9  156.246
# 2025-11-05 14:15:00-03:00  103415.9  103489.0  103375.1  103483.7   32.257
# 2025-11-05 14:16:00-03:00  103483.7  103560.0  103483.6  103509.4   49.086
# 2025-11-05 14:17:00-03:00  103509.4  103620.0  103501.4  103587.4   29.058
# 2025-11-05 14:18:00-03:00  103587.4  103587.4  103504.0  103514.5    6.830
#
# [1000 rows x 5 columns]

# %%
md.orderbook()
# Out:
#                                   ask_size  bid_size  ask_price  bid_price
# date
# 2025-11-05 18:53:53.573000+00:00  0.260072  0.677643   104326.8   104326.7

# %%
md.tickers(symbol='BTCUSDT')
# Out:
#                                  0
# Symbol                         NaN
# BidPrice                       NaN
# BidSize                        NaN
# AskPrice                       NaN
# AskSize                        NaN
# LastPrice                      NaN
# prevPrice24h              101021.9
# price24hpct                    NaN
# highPrice24h              104420.2
# lowPrice24h                98947.8
# turnover24h    1387807275.18073228
# volume24h             13677.227249
# usdIndexPrice        104347.372386

# %%
md.funding_rate()
# Out:
#       symbol  fundinRate fundingRateTimestamp
# 0    BTCUSDT         NaN        1762358400000
# 1    BTCUSDT         NaN        1762329600000
# 2    BTCUSDT         NaN        1762300800000
# 3    BTCUSDT         NaN        1762272000000
# 4    BTCUSDT         NaN        1762243200000
# ..       ...         ...                  ...
# 195  BTCUSDT         NaN        1756742400000
# 196  BTCUSDT         NaN        1756713600000
# 197  BTCUSDT         NaN        1756684800000
# 198  BTCUSDT         NaN        1756656000000
# 199  BTCUSDT         NaN        1756627200000
#
# [200 rows x 3 columns]

# %%
md.recent_trades()
# Out:
#                                    execId   symbol      price   size  side  \
# 0    430b5bdc-7915-5848-b82f-25dc7ac01bf5  BTCUSDT  104320.00  0.001   Buy
# 1    54837fda-6adb-5b8d-9e34-543a23ce535e  BTCUSDT  104320.00  0.035   Buy
# 2    a6bada5c-38b6-5763-8ba8-62e8c490a087  BTCUSDT  104320.00  0.001   Buy
# 3    ec5820a0-4350-57f2-9a21-4a1ce18988cc  BTCUSDT  104320.00  0.009   Buy
# 4    712161d0-b9b2-5681-b715-89b319f035ba  BTCUSDT  104320.00  0.001   Buy
# ..                                    ...      ...        ...    ...   ...
# 495  0fbf4edd-2f10-57d8-9e65-9b67cebb2406  BTCUSDT  104249.90  0.002  Sell
# 496  7834292d-ddad-5dc9-8601-437879cf2967  BTCUSDT  104249.90  0.025  Sell
# 497  aab6eaf2-d1a8-5752-9d0d-504a0de79a0a  BTCUSDT  104249.90  0.009  Sell
# 498  1e17afe7-1625-5f4e-83aa-802fcd08d60c  BTCUSDT  104249.90  0.009  Sell
# 499  8b60b0d2-41b1-5bc4-85a8-f8df62fed54c  BTCUSDT  104249.90  0.037  Sell
#
#               time  isBlockTrade  isRPITrade           seq
# 0    1762368851986         False       False  475999015698
# 1    1762368851042         False       False  475999014859
# 2    1762368851042         False       False  475999014859
# 3    1762368851042         False       False  475999014859
# 4    1762368850916         False       False  475999014731
# ..             ...           ...         ...           ...
# 495  1762368828005         False       False  475998819706
# 496  1762368828005         False       False  475998819706
# 497  1762368828005         False       False  475998819706
# 498  1762368828005         False       False  475998819706
# 499  1762368828005         False       False  475998819706
#
# [500 rows x 9 columns]

# %%
btc = md.price_data(symbol='BTCUSDT', interval='D')

# %%
btc
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-02-09 21:00:00-03:00   21796.73   21934.41   21480.00   21631.49
# 2023-02-10 21:00:00-03:00   21631.49   21899.60   21607.94   21863.97
# 2023-02-11 21:00:00-03:00   21863.97   22084.19   21637.60   21780.45
# 2023-02-12 21:00:00-03:00   21780.45   21888.60   21360.00   21774.06
# 2023-02-13 21:00:00-03:00   21774.06   22311.67   21533.86   22199.85
# ...                              ...        ...        ...        ...
# 2025-10-31 21:00:00-03:00  109603.10  110564.50  109385.70  110092.30
# 2025-11-01 21:00:00-03:00  110092.30  111236.50  109492.10  110539.90
# 2025-11-02 21:00:00-03:00  110539.90  110761.50  105307.40  106581.40
# 2025-11-03 21:00:00-03:00  106581.40  107294.20   98947.80  101491.70
# 2025-11-04 21:00:00-03:00  101491.70  104040.00   98961.70  103583.40
#
#                                  Volume
# Date
# 2023-02-09 21:00:00-03:00   4124.474714
# 2023-02-10 21:00:00-03:00   1343.038651
# 2023-02-11 21:00:00-03:00   1985.985647
# 2023-02-12 21:00:00-03:00   3767.184413
# 2023-02-13 21:00:00-03:00   4427.940576
# ...                                 ...
# 2025-10-31 21:00:00-03:00   3228.236938
# 2025-11-01 21:00:00-03:00   4242.129321
# 2025-11-02 21:00:00-03:00  11651.770170
# 2025-11-03 21:00:00-03:00  16369.162834
# 2025-11-04 21:00:00-03:00   8774.874069
#
# [1000 rows x 5 columns]
