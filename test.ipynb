# %%
from services.get_data import MarketData

# %%
gd = MarketData()

# %%
#gd.server_time()

# %%
gd.symbols_list()
# Out:
#          symbol baseCoin quoteCoin innovation   status marginTrading stTag  \
# 0       BTCUSDT      BTC      USDT          0  Trading       utaOnly     0
# 1       ETHUSDT      ETH      USDT          0  Trading       utaOnly     0
# 2       XRPUSDT      XRP      USDT          0  Trading       utaOnly     0
# 3        ETHBTC      ETH       BTC          0  Trading       utaOnly     0
# 4        XRPBTC      XRP       BTC          0  Trading       utaOnly     0
# ..          ...      ...       ...        ...      ...           ...   ...
# 681     METUSDC      MET      USDC          0  Trading          none     0
# 682  COMMONUSDT   COMMON      USDT          0  Trading          none     0
# 683    SYNDUSDT     SYND      USDT          0  Trading          none     0
# 684     EATUSDT      EAT      USDT          0  Trading          none     0
# 685     MMTUSDT      MMT      USDT          0  Trading          none     0
#
#                                          lotSizeFilter  \
# ...

# %%
gd.kline(category='spot',symbol='ETHUSDT')
# Out:
#                               Open     High      Low    Close        Volume
# Date
# 2023-02-08 21:00:00-03:00  1650.41  1655.79  1524.01  1545.65   61764.77206
# 2023-02-09 21:00:00-03:00  1545.65  1554.60  1491.18  1513.30   46077.94247
# 2023-02-10 21:00:00-03:00  1513.30  1543.15  1506.00  1538.78   16314.71190
# 2023-02-11 21:00:00-03:00  1538.78  1547.91  1493.56  1515.42   21038.98102
# 2023-02-12 21:00:00-03:00  1515.42  1526.06  1462.00  1505.59   55583.12617
# ...                            ...      ...      ...      ...           ...
# 2025-10-30 21:00:00-03:00  3804.80  3905.84  3796.31  3847.90  114867.28708
# 2025-10-31 21:00:00-03:00  3847.90  3909.54  3830.67  3873.80   50292.19409
# 2025-11-01 21:00:00-03:00  3873.80  3917.99  3839.29  3906.71   55987.17243
# 2025-11-02 21:00:00-03:00  3906.71  3914.99  3557.41  3603.49  232801.93060
# 2025-11-03 21:00:00-03:00  3603.49  3654.73  3335.92  3355.55  195012.28662
#
# [1000 rows x 5 columns]

# %%
gd.orderbook()
# Out:
#                                   ask_size  bid_size  ask_price  bid_price
# date
# 2025-11-04 18:13:14.873000+00:00   0.37425  0.002973   100937.7   100937.6

# %%
gd.tickers(symbol='ETHUSDT')
# Out:
#                                0
# Symbol                       NaN
# BidPrice                     NaN
# BidSize                      NaN
# AskPrice                     NaN
# AskSize                      NaN
# LastPrice                    NaN
# prevPrice24h             3664.37
# price24hpct                  NaN
# highPrice24h             3670.62
# lowPrice24h              3335.92
# turnover24h    832370143.2491923
# volume24h           235916.09728
# usdIndexPrice        3353.830942

# %%
gd.funding_rate()
# Out:
#       symbol  fundinRate fundingRateTimestamp
# 0    BTCUSDT         NaN        1762272000000
# 1    BTCUSDT         NaN        1762243200000
# 2    BTCUSDT         NaN        1762214400000
# 3    BTCUSDT         NaN        1762185600000
# 4    BTCUSDT         NaN        1762156800000
# ..       ...         ...                  ...
# 195  BTCUSDT         NaN        1756656000000
# 196  BTCUSDT         NaN        1756627200000
# 197  BTCUSDT         NaN        1756598400000
# 198  BTCUSDT         NaN        1756569600000
# 199  BTCUSDT         NaN        1756540800000
#
# [200 rows x 3 columns]

# %%
gd.recent_trades()
# Out:
#                                    execId   symbol      price   size  side  \
# 0    822317fd-8807-5db8-9691-6f21cde592a4  BTCUSDT  100802.30  0.001  Sell
# 1    f68fa7eb-80cd-5336-b5d4-6e68d8548c86  BTCUSDT  100802.90  0.001  Sell
# 2    3eaa3162-9070-5fa6-8af2-5e5533d3acf1  BTCUSDT  100803.00  0.001  Sell
# 3    5e2f8f53-5a10-5ca1-b932-7798fc70066a  BTCUSDT  100805.90  0.003  Sell
# 4    3ffbf45d-a9b5-5656-881e-e5d02ce88f2b  BTCUSDT  100805.90  0.001  Sell
# ..                                    ...      ...        ...    ...   ...
# 495  136240bf-5d55-5c94-a2b1-6c9bcfd7a2c7  BTCUSDT  100836.80  0.001  Sell
# 496  62a58d4e-776d-5a2b-a0bd-34247690b897  BTCUSDT  100838.40  0.002  Sell
# 497  702c4699-ae29-5980-93a4-dd563686b30f  BTCUSDT  100839.00  0.001  Sell
# 498  b8d39dcc-1078-54e2-a806-37a0a7ac74f0  BTCUSDT  100839.90  0.002  Sell
# 499  e861ce18-e4fa-5295-a3a3-bdaf4013da8d  BTCUSDT  100840.00  0.001  Sell
#
#               time  isBlockTrade  isRPITrade           seq
# ...
